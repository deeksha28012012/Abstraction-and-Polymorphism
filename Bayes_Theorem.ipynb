# %% [markdown]
# <a href="https://colab.research.google.com/github/deeksha28012012/Abstraction-and-Polymorphism/blob/main/Bayes_Theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def find_prob(a, b):
  if a == 1:
    prob_a = 0.2
    if b == 1:
      prob_bga = 0.85
    elif b == 2:
      prob_bga = 0.15
    else:
      print("Invalid Choice")
    prob_a_and_b = prob_a * prob_bga
    print("probability of b given a:", prob_bga)
    print("probability of both events occuring", prob_a_and_b)
  elif a==2:
    prob_a = 0.8
    if b==1:
      prob_a = 0.02
    elif b==2:
      prob_bga = 0.98
    else:
      print("Invalid Choice")
    prob_a_and_b = prob_a * prob_bga
    print("probability of b given a:", prob_bga)
    print("probability of both events occuring", prob_a_and_b)
  else:
    print("Invalid Choice")
a = int(input("Enter your choice(1/2):"))
b = int(input("Enter your choice(1/2):"))
print("pobabilities for event a and b:")
find_prob(a,b)

# %%
prob_st = 0.2
prob_st_pos = 0.2*0.85
prob_nst_pos = 0.8*0.2
prob_positive = prob_st_pos + prob_nst_pos
print(round((prob_positive),3))
# Out:
# 0.33

# %%
import numpy as np
die_sides = int(input('enter a number'))
die = range(1, die_sides)
num_rolls = int(input('enter a number'))
rolls = np.random.choice(die, size =num_rolls,replace = True)
print(rolls)
# Out:
# enter a number3
# enter a number2
# [2 1]
