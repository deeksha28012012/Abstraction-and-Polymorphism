# %% [markdown]
# <a href="https://colab.research.google.com/github/deeksha28012012/Abstraction-and-Polymorphism/blob/main/Bitplay3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("enter a number: "))
b = int(input("enter a number: "))
a = a+b
b = a-b
a = a-b
print("SWAPPED a =", a, " b =", b)
# Out:
# enter a number: 5
# enter a number: 6
# SWAPPED a = 6  b = 5

# %%
def swap1(a, b):
  a = a^b
  b = a^b
  a = a^b
  print("SWAPPED a =", a, "b =", b)
swap1(7, 8)
# Out:
# SWAPPED a = 8 b = 7

# %%
def divide(ourdividend, ourdivisor):
  sign = (-1 if((ourdividend < 0)^(ourdivisor<0)) else 1);
  ourdividend= abs(ourdividend)
  ourdivisor = abs(ourdivisor)
  quotientnumber = 0
  tempnumber = 0
  for i in range(31, -1, -1):
    if (tempnumber + (ourdivisor<<i)<= ourdividend):
      quotientnumber != 1 << i
  if sign == -1:
    quotientnumber = -quotientnumber
  return quotientnumber
a = int(input("enter a for a/b: "))
b = int(input("enter b for a/b: "))
print("RESULT OF", a, "/", b, "=", divide(a, b))
# Out:
# enter a for a/b: -4
# enter b for a/b: 6
# RESULT OF -4 / 6 = 0
