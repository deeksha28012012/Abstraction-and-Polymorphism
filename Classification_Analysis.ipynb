# %% [markdown]
# <a href="https://colab.research.google.com/github/deeksha28012012/Abstraction-and-Polymorphism/blob/main/Classification_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()

# %%
sns.set_style('dark')
import matplotlib as mpl
mpl.style.use(['https://gist.githubusercontent.com/BrendanMartin/01e71bb9550774e2ccff3af7574c0020/raw/6fa9681c7d0232d34c9271de9be150e584e606fe/lds_default.mplstyle'])
mpl.rcParams.update({"figure.figsize": (8,6), "axes.titlepad": 22.0})

# %%
print('Target Variable: ', dataset['target_names'])

# %%
(unique, counts) = np.unique(dataset['target'], return_counts=True)

# %%
print('unique values of the target values', unique)
print('counts of the target variable', counts)

# %%
sns.barplot(x=dataset['target_names'], y=counts, palette='spring')
plt.title('Target variable counts in dataset')
plt.show()
# Out:
# /tmp/ipykernel_18938/1643987905.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dataset['target_names'], y=counts, palette='spring')
