# %% [markdown]
# <a href="https://colab.research.google.com/github/deeksha28012012/Abstraction-and-Polymorphism/blob/main/Conditional_Probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def a_and_b(a,b):
  if a==1:
    prob_student = 0.3
    if b == 1:
       prob_dining = 0.75
    else:
      prob_dining = 0.25
    print("possibility of a given b: ", prob_dining)
  if a==2:
    prob_student = 0.7
    if b == 1:
      prob_dining = 0.6
    else:
      prob_dining = 0.4
    print("possibility of a given b: ", prob_dining)
  prob_a_and_b = prob_student * prob_dining
  return round(prob_a_and_b, 3)
print("is the student a freshman? \n 1. yes \n 2. no")
a = int(input("enter your choice? (1/2)"))
print("is the student eating in dining hall? \n 1. yes \n 2. no")
b = int(input("enter your choice? (1/2)"))
print(a_and_b(a,b))

# %%
def prob_a_and_b(a,b,total):
  prob_a = orange/total
  prob_b = blue/(total-1)
  prob_AandB = prob_a * prob_b
  return round(prob_AandB, 3)
orange = int(input('enter the number of orange balls: '))
blue = int(input('enter the number of blue balls:'))
total = orange+blue
print("probability of getting 1st orange ball and 2nd blue ball: ")
print(prob_a_and_b(orange,blue,total))

# %%
RS = int(input('enter the number of red shirts: '))
BS = int(input('enter the number of blue shirts: '))
WS = int(input('enter the number of white shirts: '))
total = RS+BS+WS
prob_a = BS/total
prob_b = RS/total
prob_bga = prob_b
prob_a_and_b = prob_a*prob_b
print('PROBABILITITY THAT SECOND SHIRT IS RED GIVEN THAT FIRST SHIRT IS BLUE:')
print((round(prob_bga),3))
print('PROBABILITITY THAT SECOND SHIRT IS RED THAT FIRST SHIRT IS BLUE:')
print((round(prob_a_and_b),3))
# Out:
# enter the number of red shirts: 8
# enter the number of blue shirts: 2
# enter the number of white shirts: 4
# PROBABILITITY THAT SECOND SHIRT IS RED GIVEN THAT FIRST SHIRT IS BLUE:
# (1, 3)
# PROBABILITITY THAT SECOND SHIRT IS RED THAT FIRST SHIRT IS BLUE:
# (0, 3)
