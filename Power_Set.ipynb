# %% [markdown]
# <a href="https://colab.research.google.com/github/deeksha28012012/Abstraction-and-Polymorphism/blob/main/Power_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math;
def printpowerset(set,setSize):
  powersetsize = (int) (math.pow(2, setSize));
  outer = 0;
  inner = 0;
  for outer in range(0, powersetsize):
    for inner in range(0, setSize):
      if((outer & (1 << inner))>0):
        print(set[inner], end = "")
    print("")
size = int(input("enter array size: "))
set = []
for i in range(0, size):
  n = int(input("enter array element: "))
  set.append(n)
printpowerset(set, size)
printpowerset(set, len(set))

# %%
def flips(num1, num2):
  flip = 0
  while(num1>0 or num2>0):
    t1 = num1 & 1
    t2 = num2 & 1
    if t1 != t2:
      flip += 1
      num1>>= 1
      num2>>= 1
      return flip
num1 = int(input("enter a number: "))
num2 = int(input("enter a second number: "))
print("number of flips needed: ", flips(num1, num2))
# Out:
# enter a number: 5
# enter a second number: 7
