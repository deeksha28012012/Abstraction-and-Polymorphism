# %% [markdown]
# <a href="https://colab.research.google.com/github/deeksha28012012/Abstraction-and-Polymorphism/blob/main/Statistics_for_Categorical_Variables_and_Data_Transformation_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-dfad1586-7e83-460a-b568-f829ace87707" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfad1586-7e83-460a-b568-f829ace87707">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Titanic Dataset (1).csv')

# %%
data.head(5)

# %%
data.dtypes

# %%
nominal_cat = ['Name', 'Ticket', 'Cabin']

# %%
ordinal_cat = ['Gender', 'Embarked']

# %%
data['Name'].value_counts()

# %%
gender_categories = ['Female', 'Male']

# %%
data['Name']  = pd.Categorical(data['Name'], gender_categories, ordered= True)

# %%
median_index = np.median(data['Name'].cat.codes)
median_gender = gender_categories[int(median_index)]
print(median_gender)
# Out:
# Male

# %%
data['Embarked'].value_counts()

# %%
embarked_categories = ['S', 'C', 'Q']

# %%
data['Embarked']= pd.Categorical(data['Embarked'], embarked_categories, ordered= True)

# %%
median_index = np.median(data['Embarked'].cat.codes)
median_embarked = embarked_categories[int(median_index)]
print(median_embarked)

# %%
sns.countplot(x='Survived', data=data, palette='winter')

# %%
sns.countplot(x='Gender',hue='Survived', data=data, palette='spring')

# %%
sns.countplot(x='Embarked', data=data, palette='autumn')

# %%
num_data = data.drop(['Name','Ticket','Cabin','Embarked','Gender'], axis=1)
labels = ['PassengerId','Survived','Pclass','Age','SibSp','Parch','Fare']
for label in labels:
  plt.boxplot(num_data[label])
  print('Distribution of', label)
  plt.show()
# Out:
# Distribution of PassengerId
# Distribution of Survived
# Distribution of Pclass
# Distribution of Age
# Distribution of SibSp
# Distribution of Parch
# Distribution of Fare
